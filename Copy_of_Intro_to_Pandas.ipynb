# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavatrgukt/HandwrittenDigitRecognizationUsingKNN/blob/main/Copy_of_Intro_to_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Pandas - Brief Intro
#
# 1. Data Analysis library which makes it easy to read and work with different types of data
#  * Load large amounts of data into python
#  * Work with different file formats (csv, sql, excel, etc.)
#  * Work with time-series data (stock prices, sales data, etc.)
#
# 2. Cleaning the Data and Handling Missing Values
# 3. Built on top of NumPy and has great performance
#
#
# > **Essential for everyone working with data (Data Science, ML, Analytics, etc.)**

# %% [markdown]
# # Walkthrough of Datasets

# %% [markdown]
# ## Stack Overflow Dataset

# %% [markdown]
# With nearly 65,000 responses fielded from over 180 countries and dependent territories, the 2020 Annual Developer Survey by Stack Overflow examines all aspects of the developer experience from career satisfaction and job search to education and opinions on open source software.
#
# **Source**: https://insights.stackoverflow.com/survey

# %%
# !wget https://nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com/otg_prod/media/Tech_4.0/AI_ML/Datasets/survey_results_public.csv
# Out:
# --2023-08-21 05:39:35--  https://nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com/otg_prod/media/Tech_4.0/AI_ML/Datasets/survey_results_public.csv
# Resolving nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com (nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com)... 52.219.160.86, 52.219.156.154, 52.219.160.114, ...
# Connecting to nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com (nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com)|52.219.160.86|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 94603888 (90M) [text/csv]
# Saving to: ‘survey_results_public.csv’
#
# survey_results_publ 100%[===================>]  90.22M  13.2MB/s    in 8.4s
#
# 2023-08-21 05:39:44 (10.8 MB/s) - ‘survey_results_public.csv’ saved [94603888/94603888]

# %% [markdown]
# ## Covid Dataset

# %% [markdown]
# This dataset provides day-wise metric of COVID-19 in Italy for around 200 days.
#
# **Source**: https://hub.jovian.ml/wp-content/uploads/2020/09/italy-covid-daywise.csv

# %%
# !wget https://nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com/otg_prod/media/Tech_4.0/AI_ML/Datasets/italy-covid-daywise.csv
# Out:
# --2023-08-21 05:39:58--  https://nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com/otg_prod/media/Tech_4.0/AI_ML/Datasets/italy-covid-daywise.csv
# Resolving nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com (nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com)... 3.5.211.148, 52.219.156.150, 52.219.158.26, ...
# Connecting to nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com (nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com)|3.5.211.148|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6619 (6.5K) [text/csv]
# Saving to: ‘italy-covid-daywise.csv’
#
# italy-covid-daywise 100%[===================>]   6.46K  --.-KB/s    in 0s
#
# 2023-08-21 05:39:59 (209 MB/s) - ‘italy-covid-daywise.csv’ saved [6619/6619]

# %% [markdown]
# ## Film Dataset

# %% [markdown]
# About 1000 movies with properties such as length, main actor and actress, director and popularity.
#
# **Source**: https://perso.telecom-paristech.fr/eagan/class/igr204/datasets

# %%
# !wget https://nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com/otg_prod/media/Tech_4.0/AI_ML/Datasets/film.csv
# Out:
# --2023-08-21 08:41:44--  https://nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com/otg_prod/media/Tech_4.0/AI_ML/Datasets/film.csv
# Resolving nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com (nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com)... 3.5.209.114, 52.219.156.150, 52.219.62.119, ...
# Connecting to nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com (nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com)|3.5.209.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 102889 (100K) [text/csv]
# Saving to: ‘film.csv’
#
# film.csv            100%[===================>] 100.48K   213KB/s    in 0.5s
#
# 2023-08-21 08:41:45 (213 KB/s) - ‘film.csv’ saved [102889/102889]

# %% [markdown]
# ## eCommerce Dataset

# %% [markdown]
# This dataset provides shopping data related to various products and orders over the course of a year.
#
# **Source**: https://github.com/KeithGalli/Pandas-Data-Science-Tasks

# %%
# !wget https://nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com/otg_prod/media/Tech_4.0/AI_ML/Datasets/shopping_data_v2.csv
# Out:
# --2023-08-21 05:42:47--  https://nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com/otg_prod/media/Tech_4.0/AI_ML/Datasets/shopping_data_v2.csv
# Resolving nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com (nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com)... 52.219.160.134, 52.219.66.30, 52.219.158.6, ...
# Connecting to nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com (nkb-backend-otg-media-static.s3.ap-south-1.amazonaws.com)|52.219.160.134|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16278053 (16M) [text/csv]
# Saving to: ‘shopping_data_v2.csv’
#
# shopping_data_v2.cs 100%[===================>]  15.52M  5.97MB/s    in 2.6s
#
# 2023-08-21 05:42:51 (5.97 MB/s) - ‘shopping_data_v2.csv’ saved [16278053/16278053]

# %% [markdown]
# # Reading & Writing files

# %% [markdown]
# Reading/Loading the data from a csv file

# %%
shopping_df = pd.read_csv('shopping_data_v2.csv')

# %% [markdown]
# Writing the data to a csv file

# %%
shopping_df.to_csv('shopping_data_copy.csv')

# %% [markdown]
# # Dataframe
# **A dataframe is like a dictionary of lists, but with much more functionality**
#
# *   A table of data (Rows and Columns)
# *   2 Dimensional Data Structure

# %% [markdown]
# ## Properties of a Dataframe

# %% [markdown]
# **Shape of a dataframe**

# %%
shopping_df.shape
# Out:
# (185950, 6)

# %% [markdown]
# **`df.columns` returns the column labels of a DataFrame**

# %%
shopping_df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %% [markdown]
# **`df.dtypes` returns the datatypes of each column in a DataFrame**

# %%
shopping_df.dtypes
# Out:
# Order ID              int64
# Product              object
# Quantity Ordered      int64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# dtype: object

# %% [markdown]
# ### df.head
# * `df.head(n=5)`
#   *   Returns the first `n` rows.
#   * For negative values of `n`, this function returns all the rows except for the last `n` rows.

# %%
shopping_df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
shopping_df.head(10)

# %%
shopping_df.head(-185949)
# Out:
#    Order ID               Product  Quantity Ordered  Price Each  \
# 0    176558  USB-C Charging Cable                 2       11.95
#
#        Order Date              Purchase Address
# 0  04/19/19 08:46  917 1st St, Dallas, TX 75001

# %% [markdown]
# ### df.tail
# * `df.tail(n=5)`
#   *   Returns the last `n` rows.
#   * For negative values of `n`, this function returns all rows except for the first `n` rows.

# %%
shopping_df.tail()
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each  \
# 185945    176554  Lightning Charging Cable                 1       14.95
# 185946    176555          27in FHD Monitor                 1      149.99
# 185947    176556    AAA Batteries (4-pack)                 3        2.99
# 185948    176557                    iPhone                 1      700.00
# 185949    176557  Lightning Charging Cable                 1       14.95
#
#             Order Date                           Purchase Address
# 185945  03/24/19 11:14       672 12th St, San Francisco, CA 94016
# 185946  03/22/19 20:27         42 4th St, San Francisco, CA 94016
# 185947  03/14/19 10:29          871 7th St, Los Angeles, CA 90001
# 185948  03/30/19 12:32  83 Washington St, San Francisco, CA 94016
# 185949  03/30/19 12:32  83 Washington St, San Francisco, CA 94016

# %%
shopping_df.tail(15)
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each  \
# 185935    176544  Lightning Charging Cable                 2       14.95
# 185936    176545    AAA Batteries (4-pack)                 2        2.99
# 185937    176546          Wired Headphones                 1       11.99
# 185938    176547          Wired Headphones                 2       11.99
# 185939    176548    AAA Batteries (4-pack)                 1        2.99
# 185940    176549                    iPhone                 1      700.00
# 185941    176550          Wired Headphones                 1       11.99
# 185942    176551        LG Washing Machine                 1      600.00
# 185943    176552  Apple Airpods Headphones                 1      150.00
# 185944    176553      USB-C Charging Cable                 1       11.95
# 185945    176554  Lightning Charging Cable                 1       14.95
# 185946    176555          27in FHD Monitor                 1      149.99
# 185947    176556    AAA Batteries (4-pack)                 3        2.99
# 185948    176557                    iPhone                 1      700.00
# 185949    176557  Lightning Charging Cable                 1       14.95
#
#             Order Date                            Purchase Address
# 185935  03/15/19 11:08                436 8th St, Dallas, TX 75001
# 185936  03/21/19 10:59      515 Center St, San Francisco, CA 94016
# 185937  03/21/19 16:06          3 Church St, Los Angeles, CA 90001
# 185938  03/01/19 16:39               998 Pine St, Boston, MA 02215
# 185939  03/16/19 15:36             9 Sunset St, Portland, OR 97035
# 185940  03/20/19 01:24          604 Park St, Los Angeles, CA 90001
# 185941  03/01/19 22:30       16 Sunset St, San Francisco, CA 94016
# 185942  03/20/19 23:49       567 River St, San Francisco, CA 94016
# 185943  03/08/19 14:07          578 Main St, Los Angeles, CA 90001
# 185944  03/02/19 22:27  437 Washington St, New York City, NY 10001
# 185945  03/24/19 11:14        672 12th St, San Francisco, CA 94016
# 185946  03/22/19 20:27          42 4th St, San Francisco, CA 94016
# 185947  03/14/19 10:29           871 7th St, Los Angeles, CA 90001
# 185948  03/30/19 12:32   83 Washington St, San Francisco, CA 94016
# 185949  03/30/19 12:32   83 Washington St, San Francisco, CA 94016

# %%
shopping_df.tail(-10)
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each  \
# 10        176567              Google Phone                 1      600.00
# 11        176568  Lightning Charging Cable                 1       14.95
# 12        176569    27in 4K Gaming Monitor                 1      389.99
# 13        176570     AA Batteries (4-pack)                 1        3.84
# 14        176571  Lightning Charging Cable                 1       14.95
# ...          ...                       ...               ...         ...
# 185945    176554  Lightning Charging Cable                 1       14.95
# 185946    176555          27in FHD Monitor                 1      149.99
# 185947    176556    AAA Batteries (4-pack)                 3        2.99
# 185948    176557                    iPhone                 1      700.00
# 185949    176557  Lightning Charging Cable                 1       14.95
#
#             Order Date                           Purchase Address
# 10      04/18/19 17:18          444 7th St, Los Angeles, CA 90001
# 11      04/15/19 12:18              438 Elm St, Seattle, WA 98101
# 12      04/16/19 19:23              657 Hill St, Dallas, TX 75001
# 13      04/22/19 15:09              186 12th St, Dallas, TX 75001
# 14      04/19/19 14:29          253 Johnson St, Atlanta, GA 30301
# ...                ...                                        ...
# 185945  03/24/19 11:14       672 12th St, San Francisco, CA 94016
# 185946  03/22/19 20:27         42 4th St, San Francisco, CA 94016
# 185947  03/14/19 10:29          871 7th St, Los Angeles, CA 90001
# 185948  03/30/19 12:32  83 Washington St, San Francisco, CA 94016
# 185949  03/30/19 12:32  83 Washington St, San Francisco, CA 94016
#
# [185940 rows x 6 columns]

# %% [markdown]
# ### df.describe
# * `df.describe(include=None, exclude=None)`
#   * Generates descriptive statistics.
#   * Analyzes both numeric and object series as well as mixed data types.
#   * `include`: A list of data types to include in the result.
#   * `exclude`:  A list of data types to omit from the result.

# %%
shopping_df.describe()
# Out:
#             Order ID  Quantity Ordered     Price Each
# count  185950.000000     185950.000000  185950.000000
# mean   230417.569379          1.124383     184.399735
# std     51512.737110          0.442793     332.731330
# min    141234.000000          1.000000       2.990000
# 25%    185831.250000          1.000000      11.950000
# 50%    230367.500000          1.000000      14.950000
# 75%    275035.750000          1.000000     150.000000
# max    319670.000000          9.000000    1700.000000

# %%
shopping_df.describe(include=[object])
# Out:
#                      Product      Order Date  \
# count                 185950          185950
# unique                    19          142395
# top     USB-C Charging Cable  12/15/19 20:16
# freq                   21903               8
#
#                               Purchase Address
# count                                   185950
# unique                                  140787
# top     193 Forest St, San Francisco, CA 94016
# freq                                         9

# %%
shopping_df.describe(include="all")
# Out:
#              Order ID               Product  Quantity Ordered     Price Each  \
# count   185950.000000                185950     185950.000000  185950.000000
# unique            NaN                    19               NaN            NaN
# top               NaN  USB-C Charging Cable               NaN            NaN
# freq              NaN                 21903               NaN            NaN
# mean    230417.569379                   NaN          1.124383     184.399735
# std      51512.737110                   NaN          0.442793     332.731330
# min     141234.000000                   NaN          1.000000       2.990000
# 25%     185831.250000                   NaN          1.000000      11.950000
# 50%     230367.500000                   NaN          1.000000      14.950000
# 75%     275035.750000                   NaN          1.000000     150.000000
# max     319670.000000                   NaN          9.000000    1700.000000
#
#             Order Date                        Purchase Address
# count           185950                                  185950
# unique          142395                                  140787
# top     12/15/19 20:16  193 Forest St, San Francisco, CA 94016
# freq                 8                                       9
# mean               NaN                                     NaN
# std                NaN                                     NaN
# min                NaN                                     NaN
# 25%                NaN                                     NaN
# 50%                NaN                                     NaN
# 75%                NaN                                     NaN
# max                NaN                                     NaN

# %%
shopping_df.describe(exclude=[object])
# Out:
#             Order ID  Quantity Ordered     Price Each
# count  185950.000000     185950.000000  185950.000000
# mean   230417.569379          1.124383     184.399735
# std     51512.737110          0.442793     332.731330
# min    141234.000000          1.000000       2.990000
# 25%    185831.250000          1.000000      11.950000
# 50%    230367.500000          1.000000      14.950000
# 75%    275035.750000          1.000000     150.000000
# max    319670.000000          9.000000    1700.000000

# %% [markdown]
# ### df.info
# * `df.info()`
#   * Print a concise summary of a DataFrame including the dtypes of the columns, memory usage, etc.

# %%
shopping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  int64
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 8.5+ MB

# %% [markdown]
# ## Comparision with Dictionary of Lists

# %%
people = {
    "first": ["Kristen", 'Maxine', 'John'],
    "last": ["Carol", 'Willians', 'Smith'],
    "email": ["KristenC@gmail.com", 'Maxine.Williams@email.com', 'JohnSmith@email.com']
}

# %% [markdown]
# Creating DataFrame from a dictionary of lists

# %%
df = pd.DataFrame(people)
print(df)
# Out:
#      first      last                      email
# 0  Kristen     Carol         KristenC@gmail.com
# 1   Maxine  Willians  Maxine.Williams@email.com
# 2     John     Smith        JohnSmith@email.com

# %%
people["first"]
# Out:
# ['Kristen', 'Maxine', 'John']

# %%
df["last"]
# Out:
# 0       Carol
# 1    Willians
# 2       Smith
# Name: last, dtype: object

# %%
type(df["first"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Series
# **A Series is like a list of data, but with much more functionality**

# %% [markdown]
# Creating Series from a List of Data

# %%
pd.Series([1, 2, 3, 4, "asdf"])
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4    asdf
# dtype: object

# %%
type(shopping_df['Product'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Accessing Data

# %% [markdown]
# ## Indexing

# %% [markdown]
# We can retrieve a specific value from a series using the indexing notation **`[]`**

# %%
shopping_df['Product'][200]
# Out:
# 'AA Batteries (4-pack)'

# %% [markdown]
# ### df.iloc
#
# **Accessing by position numbers**
#
# * `df.iloc()`
#
#   * Purely integer-location based indexing for selection by position.
#   * Unlike in `loc`, if a slice object with indices is passed then **stop is excluded**

# %%
shopping_df.iloc[0:4]
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
df=pd.DataFrame([[1,2],[4,5],[7,8]],index=[7,8,9],columns=["max","min"])
df.loc[7:9]
# Out:
#    max  min
# 7    1    2
# 8    4    5
# 9    7    8

# %%
shopping_df.iloc[0, 1]

# %% [markdown]
# ### df.loc
#
# **Accessing by label / name**
#
# * `df.loc()`
#
#   * Access a group of rows and columns by label(s) or a boolean array
#   * Allowed inputs are:
#     * single label
#     * list or array of labels
#     * slice object with labels (**both start and stop are included**)
#     * boolean array of the same length as the axis being sliced

# %%
shopping_df.loc[980]
# Out:
# Order ID                                     177494
# Product                       AA Batteries (4-pack)
# Quantity Ordered                                  1
# Price Each                                     3.84
# Order Date                           04/22/19 05:37
# Purchase Address    480 North St, Seattle, WA 98101
# Name: 980, dtype: object

# %%
shopping_df.loc[[980, 456]]
# Out:
#      Order ID                Product  Quantity Ordered  Price Each  \
# 980    177494  AA Batteries (4-pack)                 1        3.84
# 456    176995  AA Batteries (4-pack)                 2        3.84
#
#          Order Date                     Purchase Address
# 980  04/22/19 05:37      480 North St, Seattle, WA 98101
# 456  04/20/19 23:12  964 8th St, San Francisco, CA 94016

# %%
shopping_df.loc[[980, 456], ['Product', 'Order Date']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-bafee3fe7ae0> in <cell line: 1>()
# ----> 1 shopping_df.loc[[980, 456], ['Product', 'Order Date']]
#
# NameError: name 'shopping_df' is not defined

# %%
shopping_df.loc[45, 'Product']
# Out:
# 'Lightning Charging Cable'

# %%
shopping_df[0:3]
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# ### df.at
# * `df.at()`
#   * Access a single value for a row/column label pair.
#   * Can also set/update a value at a specified row/column pair
#   * Use `at` only if you need to get or set a single value in a DataFrame or Series.

# %%
shopping_df.at[50000, 'Product']
# Out:
# 'AA Batteries (4-pack)'

# %%
df_copy = shopping_df.copy()

# %%
print(df_copy.at[50000, 'Product'])
df_copy.at[50000, 'Product'] = "Micro USB Cable"
print(df_copy.at[50000, 'Product'], "\n")

print(shopping_df.at[50000, 'Product'])

# %% [markdown]
# ## Slicing

# %%
shopping_df[0:3]

# %% [markdown]
# When slicing using **loc** the start and stop indices are **included**.

# %%
shopping_df.loc[7:9]

# %%
shopping_df.loc[23:45, 'Product']

# %%
shopping_df.loc[10:20, 'Product':'Order Date']
# Out:
#                      Product  Quantity Ordered  Price Each      Order Date
# 10              Google Phone                 1      600.00  04/18/19 17:18
# 11  Lightning Charging Cable                 1       14.95  04/15/19 12:18
# 12    27in 4K Gaming Monitor                 1      389.99  04/16/19 19:23
# 13     AA Batteries (4-pack)                 1        3.84  04/22/19 15:09
# 14  Lightning Charging Cable                 1       14.95  04/19/19 14:29
# 15  Apple Airpods Headphones                 1      150.00  04/04/19 20:30
# 16      USB-C Charging Cable                 1       11.95  04/27/19 18:41
# 17              Google Phone                 1      600.00  04/03/19 19:42
# 18      USB-C Charging Cable                 1       11.95  04/03/19 19:42
# 19    AAA Batteries (4-pack)                 1        2.99  04/27/19 00:30
# 20  Apple Airpods Headphones                 1      150.00  04/28/19 11:42

# %% [markdown]
# When slicing using **iloc** the stop index is **excluded**.

# %%
shopping_df.iloc[1, 0:3]
# Out:
# Order ID                                176559
# Product             Bose SoundSport Headphones
# Quantity Ordered                             1
# Name: 1, dtype: object

# %%
shopping_df.iloc[1, 0:3]

# %% [markdown]
# # Try It Yourself

# %% [markdown]
# For the following questions, use the **film** dataset.
# 0. Load the dataset into a dataframe using `read_csv`
# 1. Get the shape of the dataset.
# 2. Get the names of the first 6 films.
# 3. Generate descriptive statistics for the dataset, including all datatypes.
# 4. Change the 'Popularity' at the third index to 70.
# 5. Get the data in the first two columns for the last five rows in the dataset.

# %%
film_df=pd.read_csv("film.csv")
film_df.shape
# Out:
# (1128, 9)

# %%
film_df.head(5)
# Out:
#    Year  Length                    Title Subject                Actor  \
# 0  1990     111  Tie Me Up! Tie Me Down!  Comedy    Banderas, Antonio
# 1  1991     113               High Heels  Comedy         Bosé, Miguel
# 2  1983     104           Dead Zone, The  Horror  Walken, Christopher
# 3  1979     122                     Cuba  Action        Connery, Sean
# 4  1978      94           Days of Heaven   Drama        Gere, Richard
#
#            Actress           Director  Popularity Awards
# 0  Abril, Victoria   Almodóvar, Pedro          68     No
# 1  Abril, Victoria   Almodóvar, Pedro          68     No
# 2    Adams, Brooke  Cronenberg, David          79     No
# 3    Adams, Brooke    Lester, Richard           6     No
# 4    Adams, Brooke   Malick, Terrence          14     No

# %%
film_df.describe(include="all")
# Out:
#                Year       Length                      Title Subject  \
# count   1128.000000  1128.000000                       1128    1128
# unique          NaN          NaN                       1127      15
# top             NaN          NaN  Island of Dr. Moreau, The   Drama
# freq            NaN          NaN                          2     490
# mean    1975.243794   108.290780                        NaN     NaN
# std       16.615917    29.299461                        NaN     NaN
# min     1924.000000    18.000000                        NaN     NaN
# 25%     1966.750000    94.000000                        NaN     NaN
# 50%     1982.000000   103.000000                        NaN     NaN
# 75%     1988.000000   117.000000                        NaN     NaN
# max     1997.000000   450.000000                        NaN     NaN
#
#               Actor          Actress         Director   Popularity Awards
# count          1128             1128             1128  1128.000000   1128
# unique          591              652              643          NaN      2
# top     Wayne, John  Bergman, Ingrid  Bergman, Ingmar          NaN     No
# freq             35               25               28          NaN    990
# mean            NaN              NaN              NaN    43.850177    NaN
# std             NaN              NaN              NaN    26.912387    NaN
# min             NaN              NaN              NaN     0.000000    NaN
# 25%             NaN              NaN              NaN    19.000000    NaN
# 50%             NaN              NaN              NaN    44.500000    NaN
# 75%             NaN              NaN              NaN    68.000000    NaN
# max             NaN              NaN              NaN    88.000000    NaN

# %%
film_df[0:5]["Title"]
# Out:
# 0    Tie Me Up! Tie Me Down!
# 1                 High Heels
# 2             Dead Zone, The
# 3                       Cuba
# 4             Days of Heaven
# Name: Title, dtype: object

# %%
film_df[0:10]["Popularity"]
# Out:
# 0    68
# 1    68
# 2    79
# 3    70
# 4    14
# 5    68
# 6    14
# 7    28
# 8     6
# 9    32
# Name: Popularity, dtype: int64

# %%
film_df["Popularity"][2]=90
film_df[0:3]["Popularity"]
# Out:
# <ipython-input-23-89ef8f142d06>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   film_df["Popularity"][2]=90
# 0    68
# 1    68
# 2    90
# Name: Popularity, dtype: int64

# %%
film_df.loc[5:1:-1,:"Title"]
# Out:
#    Year  Length           Title
# 5  1983     140       Octopussy
# 4  1978      94  Days of Heaven
# 3  1979     122            Cuba
# 2  1983     104  Dead Zone, The
# 1  1991     113      High Heels

# %%
film_df.tail(5)
# Out:
#       Year  Length               Title          Subject             Actor  \
# 1123  1975      93    That Lucky Touch           Action      Moore, Roger
# 1124  1949      90       Lust for Gold            Drama       Ford, Glenn
# 1125  1987     103                Heat          Mystery    Reynolds, Burt
# 1126  1947      87  Night Is My Future            Drama  Malmsten, Birger
# 1127  1990      92        Witches, The  Science Fiction     Fisher, Jasen
#
#               Actress            Director  Popularity Awards
# 1123   York, Susannah  Miles, Christopher          85     No
# 1124       Young, Gig    Simon, S. Sylvan          57     No
# 1125     Young, Karen      Jameson, Jerry          69     No
# 1126  Zetterling, Mai     Bergman, Ingmar          17     No
# 1127  Zetterling, Mai       Roeg, Nicolas          18     No
